# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
pgto = list(loja['Tipo de pagamento'])
pgto2 = list(loja2['Tipo de pagamento'])
pgto3 = list(loja3['Tipo de pagamento'])
pgto4 = list(loja4['Tipo de pagamento'])

# %%
boleto = pgto.count('boleto')
credito = pgto.count('cartao_credito')
debito = pgto.count('cartao_debito')
cupom = pgto.count('cupom')
boleto2 = pgto2.count('boleto')
credito2 = pgto2.count('cartao_credito')
debito2 = pgto2.count('cartao_debito')
cupom2 = pgto2.count('cupom')
boleto3 = pgto3.count('boleto')
credito3 = pgto3.count('cartao_credito')
debito3 = pgto3.count('cartao_debito')
cupom3 = pgto3.count('cupom')
boleto4 = pgto4.count('boleto')
credito4 = pgto4.count('cartao_credito')
debito4 = pgto4.count('cartao_debito')
cupom4 = pgto4.count('cupom')
print(boleto, credito, debito, cupom)
print(boleto2, credito2, debito2, cupom2)
print(boleto3, credito3, debito3, cupom3)
print(boleto4, credito4, debito4, cupom4)
# Out:
# 483 1704 35 137
# 467 1721 30 141
# 468 1753 37 101
# 482 1720 31 125

# %%
frete = round(sum(loja['Frete']) / len(loja['Frete']),2)
frete
# Out:
# 34.69

# %% [markdown]
# #1. Análise do faturamento

# %%
from babel.numbers import format_currency
preco_loja = round(sum(loja['Preço']),2)
vendas_loja = format_currency(preco_loja, 'BRL', locale='pt_BR')
preco_loja2 = round(sum(loja2['Preço']),2)
vendas_loja2 = format_currency(preco_loja2, 'BRL', locale='pt_BR')
preco_loja3 = round(sum(loja3['Preço']),2)
vendas_loja3 = format_currency(preco_loja3, 'BRL', locale='pt_BR')
preco_loja4 = round(sum(loja4['Preço']),2)
vendas_loja4 = format_currency(preco_loja4, 'BRL', locale='pt_BR')
print(f'loja 1 vendeu: {vendas_loja},\n loja 2 vendeu: {vendas_loja2},\n loja 3 vendeu: {vendas_loja3},\n loja 4 vendeu: {vendas_loja4}.')
faturamento = [preco_loja, preco_loja2, preco_loja3, preco_loja4]
faturamento
# Out:
# loja 1 vendeu: R$ 1.534.509,12,
#  loja 2 vendeu: R$ 1.488.459,06,
#  loja 3 vendeu: R$ 1.464.025,03,
#  loja 4 vendeu: R$ 1.384.497,58.
# [1534509.12, 1488459.06, 1464025.03, 1384497.58]

# %% [markdown]
# loja 1 vendeu: R$ 1.534.509,12,
#
# loja 2 vendeu: R$ 1.488.459,06,
#
# loja 3 vendeu: R$ 1.464.025,03,
#
# loja 4 vendeu: R$ 1.384.497,58.

# %%
total_faturado = (preco_loja + preco_loja2 + preco_loja3 + preco_loja4)
total_faturado
# Out:
# 5871490.79

# %%
from matplotlib import pyplot as plt
labels = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
sizes = [preco_loja, preco_loja2, preco_loja3, preco_loja4]
colors = ['pink', 'skyblue', 'yellow', 'green']
explode = (0,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Faturamento por loja')
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %% [markdown]
# categorias do produto unicas:
# 'moveis',
# 'esporte e lazer',
# 'utilidades domesticas',
# 'livros',
# 'eletrodomesticos',
# 'eletronicos',
# 'brinquedos',
# 'instrumentos musicais'

# %%
categorias = list(loja['Categoria do Produto'])
moveis = categorias.count('moveis')
esporte = categorias.count('esporte e lazer')
utilidades =categorias.count('utilidades domesticas')
livros = categorias.count('livros')
eletrodomesticos = categorias.count('eletrodomesticos')
eletronicos = categorias.count('eletronicos')
brinquedos = categorias.count('brinquedos')
instrumentos = categorias.count('instrumentos musicais')
categorias2 = list(loja2['Categoria do Produto'])
moveis2 = categorias2.count('moveis')
esporte2 = categorias2.count('esporte e lazer')
utilidades2 =categorias2.count('utilidades domesticas')
livros2 = categorias2.count('livros')
eletrodomesticos2 = categorias2.count('eletrodomesticos')
eletronicos2 = categorias2.count('eletronicos')
brinquedos2 = categorias2.count('brinquedos')
instrumentos2 = categorias2.count('instrumentos musicais')
categorias3 = list(loja3['Categoria do Produto'])
moveis3 = categorias3.count('moveis')
esporte3 = categorias3.count('esporte e lazer')
utilidades3 =categorias3.count('utilidades domesticas')
livros3 = categorias3.count('livros')
eletrodomesticos3 = categorias3.count('eletrodomesticos')
eletronicos3 = categorias3.count('eletronicos')
brinquedos3 = categorias3.count('brinquedos')
instrumentos3 = categorias3.count('instrumentos musicais')
categorias4 = list(loja4['Categoria do Produto'])
moveis4 = categorias4.count('moveis')
esporte4 = categorias4.count('esporte e lazer')
utilidades4 =categorias4.count('utilidades domesticas')
livros4 = categorias4.count('livros')
eletrodomesticos4 = categorias4.count('eletrodomesticos')
eletronicos4 = categorias4.count('eletronicos')
brinquedos4 = categorias4.count('brinquedos')
instrumentos4 = categorias4.count('instrumentos musicais')
print(f'Moveis:\n loja 1: {moveis}\n loja 2: {moveis2}\n loja 3: {moveis3}\n loja 4: {moveis4}.')
print(f'Esporte e lazer:\n loja 1: {esporte}\n loja 2: {esporte2}\n loja 3: {esporte3}\n loja 4: {esporte4}.')
print(f'Utilidades domesticas:\n loja 1: {utilidades}\n loja 2: {utilidades2}\n loja 3: {utilidades3}\n loja 4: {utilidades4}.')
print(f'Livros:\n loja 1: {livros}\n loja 2: {livros2}\n loja 3: {livros3}\n loja 4: {livros4}.')
print(f'Eletrodomesticos:\n loja 1: {eletrodomesticos}\n loja 2: {eletrodomesticos2}\n loja 3: {eletrodomesticos3}\n loja 4: {eletrodomesticos4}.')
print(f'Eletronicos:\n loja 1: {eletronicos}\n loja 2: {eletronicos2}\n loja 3: {eletronicos3}\n loja 4: {eletronicos4}.')
print(f'Brinquedos:\n loja 1: {brinquedos}\n loja 2: {brinquedos2}\n loja 3: {brinquedos3}\n loja 4: {brinquedos4}.')
print(f'Instrumentos musicais:\n loja 1: {instrumentos}\n loja 2: {instrumentos2}\n loja 3: {instrumentos3}\n loja 4: {instrumentos4}.')
# Out:
# Moveis:
#  loja 1: 465
#  loja 2: 442
#  loja 3: 499
#  loja 4: 480.
# Esporte e lazer:
#  loja 1: 284
#  loja 2: 275
#  loja 3: 277
#  loja 4: 277.
# Utilidades domesticas:
#  loja 1: 171
#  loja 2: 181
#  loja 3: 177
#  loja 4: 201.
# Livros:
#  loja 1: 173
#  loja 2: 197
#  loja 3: 185
#  loja 4: 187.
# Eletrodomesticos:
#  loja 1: 312
#  loja 2: 305
#  loja 3: 278
#  loja 4: 254.
# Eletronicos:
#  loja 1: 448
#  loja 2: 422
#  loja 3: 451
#  loja 4: 451.
# Brinquedos:
#  loja 1: 324
#  loja 2: 313
#  loja 3: 315
#  loja 4: 338.
# Instrumentos musicais:
#  loja 1: 182
#  loja 2: 224
#  loja 3: 177
#  loja 4: 170.

# %%
qtd_vendas = [moveis, esporte, utilidades, livros, eletrodomesticos, eletronicos, brinquedos,instrumentos]
qtd_vendas2 = [moveis2, esporte2, utilidades2, livros2, eletrodomesticos2, eletronicos2, brinquedos2,instrumentos2]
qtd_vendas3 = [moveis3, esporte3, utilidades3, livros3, eletrodomesticos3, eletronicos3, brinquedos3,instrumentos3]
qtd_vendas4 = [moveis4, esporte4, utilidades4, livros4, eletrodomesticos4, eletronicos4, brinquedos4,instrumentos4]
print('moveis, esporte, utilidades, livros, eletrodo, eletroni, brinquedos, instrumentos')
print(f'loja1: {qtd_vendas}')
print(f'loja2: {qtd_vendas2}')
print(f'loja3: {qtd_vendas3}')
print(f'loja4: {qtd_vendas4}')
# Out:
# moveis, esporte, utilidades, livros, eletrodo, eletroni, brinquedos, instrumentos
# loja1: [465, 284, 171, 173, 312, 448, 324, 182]
# loja2: [442, 275, 181, 197, 305, 422, 313, 224]
# loja3: [499, 277, 177, 185, 278, 451, 315, 177]
# loja4: [480, 277, 201, 187, 254, 451, 338, 170]

# %%
labels = ['Moveis', 'Esporte', 'Uti.Domes', 'Livros', 'Eletrodom', 'Eletroele', 'Brinquedos', 'Inst.Musicais']
sizes = qtd_vendas2
colors = ['yellow', 'green', 'lightskyblue', 'pink']
explode = (0,0,0,0,0,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('vendas da loja por categorias')
plt.show()

# %%
import numpy as np
categorias = ['moveis', 'esporte', 'utilidades', 'livros', 'eletrodo', 'eletroni', 'brinquedos', 'instrumentos']
largura = 0.2
x = np.arange(len(categorias))
fig, ax = plt.subplots()
barra1 = ax.bar(x, qtd_vendas, largura, label = 'loja 1', color= 'pink')
barra2 = ax.bar(x +0.2, qtd_vendas2, largura, label = 'loja 2', color= 'skyblue')
barra3 = ax.bar(x +0.4, qtd_vendas3, largura, label = 'loja 3', color= 'yellow')
barra4 = ax.bar(x +0.6, qtd_vendas4, largura, label = 'loja 4', color= 'green')
ax.set_xlabel('Categorias')
ax.set_ylabel('Quantidade')
ax.set_title('Comparativo entre lojas')
ax.set_xticklabels(categorias)
ax.legend()
plt.show()
# Out:
# <ipython-input-92-ce9f32c4cfc1>:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(categorias)

# %%
tabela = [('loja', 'loja1', 'loja2', 'loja3', 'loja4')]
tabela += [(qtd_vendas[i], qtd_vendas2[i], qtd_vendas3[i], qtd_vendas4[i]) for i in range(len(qtd_vendas))]
tabela
# Out:
# [('loja', 'loja1', 'loja2', 'loja3', 'loja4'),
#  (465, 442, 499, 480),
#  (284, 275, 277, 277),
#  (171, 181, 177, 201),
#  (173, 197, 185, 187),
#  (312, 305, 278, 254),
#  (448, 422, 451, 451),
#  (324, 313, 315, 338),
#  (182, 224, 177, 170)]

# %% [markdown]
# ('l1,-- l2,----  l3,---- l4')
#
#  (465, 442, 499, 480), moveis
#
#  (284, 275, 277, 277), esporte e lazer
#
#  (171, 181, 177, 201), utilidades domesticas
#
#  (173, 197, 185, 187), livros
#
#  (312, 305, 278, 254), eletrodomesticos
#
#  (448, 422, 451, 451), eletronicos
#
#  (324, 313, 315, 338), brinquedos
#
#  (182, 224, 177, 170) instrumentos musicais

# %%
qtdVendas_loja = sum(qtd_vendas)
qtdVendas_loja2 = sum(qtd_vendas2)
qtdVendas_loja3 = sum(qtd_vendas3)
qtdVendas_loja4 = sum(qtd_vendas4)
print(qtdVendas_loja, qtdVendas_loja2, qtdVendas_loja3, qtdVendas_loja4)
# Out:
# 2359 2359 2359 2358

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
avaliacao = list(loja['Avaliação da compra'])
avaliacao2 = list(loja2['Avaliação da compra'])
avaliacao3 = list(loja3['Avaliação da compra'])
avaliacao4 = list(loja4['Avaliação da compra'])
aval_loja = round(sum(avaliacao) / len(avaliacao),2)
aval_loja2 = round(sum(avaliacao2) / len(avaliacao2),2)
aval_loja3 = round(sum(avaliacao3) / len(avaliacao3),2)
aval_loja4 = round(sum(avaliacao4) / len(avaliacao4),2)
print(f'A avaliação da loja 1 tem média: {round(aval_loja,2)}, da loja 2: {round(aval_loja2,2)}, da loja 3: {round(aval_loja3,2)}, da loja 4: {round(aval_loja4,2)}')
# Out:
# A avaliação da loja 1 tem média: 3.98, da loja 2: 4.04, da loja 3: 4.05, da loja 4: 4.0

# %% [markdown]
# A avaliação média das lojas é a seguinte:
#
# da loja 1: 3.98;
#
# da loja 2: 4.04;
#
# da loja 3: 4.05;
#
# da loja 4: 4.0.

# %%
categorias = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
valores = [aval_loja, aval_loja2, aval_loja3, aval_loja4]
cores = ['pink', 'skyblue', 'yellow', 'green']
plt.barh(categorias, valores, color=cores)
for index, value in enumerate(valores):
  plt.text(value, index, str(value))
plt.xlabel('Nota')
plt.ylabel('Loja')
plt.title('Médias de avalição por loja')
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
mais_vendido = max(qtd_vendas)
mais_vendido2 = max(qtd_vendas2)
mais_vendido3 = max(qtd_vendas3)
mais_vendido4 = max(qtd_vendas4)
print(mais_vendido, mais_vendido2, mais_vendido3, mais_vendido4)
# Out:
# 465 442 499 480

# %% [markdown]
# Em todas as lojas os itens mais vendidos foram MOVEIS.

# %%
menos_vendido = min(qtd_vendas)
menos_vendido2 = min(qtd_vendas2)
menos_vendido3 = min(qtd_vendas3)
menos_vendido4 = min(qtd_vendas4)
print(menos_vendido, menos_vendido2, menos_vendido3, menos_vendido4)
# Out:
# 171 181 177 170

# %% [markdown]
# Nas lojas 1 e 2, os itens menos vendidos foram de UTILIDADES DOMESTICAS;
#
# Na loja 3 UTILIDADES DOMESTICAS e INSTRUMENTOS MUSICAIS foram os menos vendidos;
#
# na loja 4 os menos vendidos foram os INSTRUMENTOS MUSICAIS.

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete = round(sum(loja['Frete']) / len(loja['Frete']),2)
frete2 = round(sum(loja2['Frete']) / len(loja2['Frete']),2)
frete3 = round(sum(loja3['Frete']) / len(loja3['Frete']),2)
frete4 = round(sum(loja4['Frete']) / len(loja4['Frete']),2)
print(f'O custo médio do frete para a loja 1 foi de: R${frete};\nPara a loja 2 foi de: R${frete2};\nPara a loja 3 foi de: R${frete3}\nPara a loja 4 foi de: R${frete4}')
# Out:
# O custo médio do frete para a loja 1 foi de: R$34.69;
# Para a loja 2 foi de: R$33.62;
# Para a loja 3 foi de: R$33.07
# Para a loja 4 foi de: R$31.28

# %% [markdown]
# Custo médio de frete por loja:
#
# Loja 1: R$34,69;
#
# Loja 2: R$33,62;
#
# Loja 3: R$33,07;
#
# Loja 4: R$31,28.

# %%
categorias = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
valores = [frete, frete2, frete3, frete4]
cores = ['pink', 'skyblue', 'yellow', 'green']
plt.barh(categorias, valores, color=cores)
for index, value in enumerate(valores):
  plt.text(value, index, str(value))
plt.xlabel('Frete')
plt.ylabel('Loja')
plt.title('Médias de frete por loja')
plt.show()

# %%
from matplotlib import pyplot as plt
labels = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
sizes = [preco_loja, preco_loja2, preco_loja3, preco_loja4]
colors = ['pink', 'skyblue', 'yellow', 'green']
explode = (0,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Faturamento por loja')
plt.show()
categorias = ['moveis', 'esporte', 'utilidades', 'livros', 'eletrodo', 'eletroni', 'brinquedos', 'instrumentos']
largura = 0.2
x = np.arange(len(categorias))
fig, ax = plt.subplots()
barra1 = ax.bar(x, qtd_vendas, largura, label = 'loja 1', color= 'pink')
barra2 = ax.bar(x +0.2, qtd_vendas2, largura, label = 'loja 2', color= 'skyblue')
barra3 = ax.bar(x +0.4, qtd_vendas3, largura, label = 'loja 3', color= 'yellow')
barra4 = ax.bar(x +0.6, qtd_vendas4, largura, label = 'loja 4', color= 'green')
ax.set_xlabel('Categorias')
ax.set_ylabel('Quantidade')
ax.set_title('Comparativo entre lojas')
ax.set_xticklabels(categorias)
ax.legend()
plt.show()
categorias = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
valores = [aval_loja, aval_loja2, aval_loja3, aval_loja4]
cores = ['pink', 'skyblue', 'yellow', 'green']
plt.barh(categorias, valores, color=cores)
for index, value in enumerate(valores):
  plt.text(value, index, str(value))
plt.xlabel('Nota')
plt.ylabel('Loja')
plt.title('Médias de avalição por loja')
plt.show()
# Out:
# <ipython-input-93-a46126f81e01>:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(categorias)

# %% [markdown]
# ## RELATÓRIO FINAL:

# %% [markdown]
# Conforme foi solicitado pelo Sr. João, segue relatorio referente a analise de informações para auxiliar na tomada de decisão sobre qual das suas quatro loja o mesmo poderia vender para levantar capital e realizar novos investimentos.
#
# Após analisar todas as informações fornecidas, percebe-se que a loja de número 4 foi a que menos vendeu em comparação com as outras, tanto em termos de valor total faturado quanto de desempenho geral. Embora tenha recebido uma boa avaliação e seu custo médio de frete tenha sido o menor, o que pode indicar que os clientes são atraídos por ela, isso não foi suficiente para garantir um bom desempenho.
#
# Em termos de resultados, essa loja seria a escolha mais adequada para venda, pois, apesar do frete baixo, seu desempenho geral é inferior ao das outras três lojas. Assim, ela se torna a menos atrativa para o grupo e apresenta o menor faturamento.
#
# Ainda assim, é uma loja com boas vendas e, possivelmente, seus números podem melhorar sob a gestão de novos administradores e com a implementação de novas abordagens. O que pode ser um ponto forte na hora de sua venda.
